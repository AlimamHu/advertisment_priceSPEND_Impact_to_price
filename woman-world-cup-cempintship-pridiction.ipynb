# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/womens-march-mania-2022/WDataFiles_Stage1/Conferences.csv
# /kaggle/input/womens-march-mania-2022/WDataFiles_Stage1/WNCAATourneyDetailedResults.csv
# /kaggle/input/womens-march-mania-2022/WDataFiles_Stage1/WSampleSubmissionStage1.csv
# /kaggle/input/womens-march-mania-2022/WDataFiles_Stage1/WRegularSeasonCompactResults.csv
# /kaggle/input/womens-march-mania-2022/WDataFiles_Stage1/WGameCities.csv
# /kaggle/input/womens-march-mania-2022/WDataFiles_Stage1/WNCAATourneySlots.csv
# /kaggle/input/womens-march-mania-2022/WDataFiles_Stage1/Cities.csv
# /kaggle/input/womens-march-mania-2022/WDataFiles_Stage1/WTeams.csv
# /kaggle/input/womens-march-mania-2022/WDataFiles_Stage1/WNCAATourneyCompactResults.csv
# /kaggle/input/womens-march-mania-2022/WDataFiles_Stage1/WSeasons.csv
# /kaggle/input/womens-march-mania-2022/WDataFiles_Stage1/WNCAATourneySeeds.csv
# /kaggle/input/womens-march-mania-2022/WDataFiles_Stage1/WRegularSeasonDetailedResults.csv
# ...

# %% [markdown]
# # take a quick overView of the dataSets

# %%
import pandas as pd
import numpy as np
from IPython.display import display

# %%
pd.set_option('display.max_columns',40)     # increase many columns values

data_path= r"../input/womens-march-mania-2022/WDataFiles_Stage1/"    # the path of where all file

import os 
file_name_list=os.listdir(data_path)   # convert all file into list

# %% [markdown]
# ```
# In:  print(data_path+file_name_list[6])
# Out: "../input/womens-march-mania-2022/WDataFiles_Stage1/Cities.csv"
# ```
# **All dataSets**

# %%
def list_all_file_name():
    for i,v in enumerate(file_name_list):
        print(i,"-",v)
list_all_file_name()
# Out:
# 0 - Conferences.csv
# 1 - WNCAATourneyDetailedResults.csv
# 2 - WSampleSubmissionStage1.csv
# 3 - WRegularSeasonCompactResults.csv
# 4 - WGameCities.csv
# 5 - WNCAATourneySlots.csv
# 6 - Cities.csv
# 7 - WTeams.csv
# 8 - WNCAATourneyCompactResults.csv
# 9 - WSeasons.csv
# 10 - WNCAATourneySeeds.csv
# 11 - WRegularSeasonDetailedResults.csv
# 12 - WTeamSpellings.csv
# 13 - WTeamConferences.csv

# %%
# new era

# %%
city=pd.read_csv(data_path+file_name_list[6])

# %%
city
# Out:
#      CityID                 City State
# 0      4001              Abilene    TX
# 1      4002                Akron    OH
# 2      4003               Albany    NY
# 3      4004          Albuquerque    NM
# 4      4005            Allentown    PA
# ..      ...                  ...   ...
# 458    4481  San Juan Capistrano    CA
# 459    4482             St. Paul    MN
# 460    4483               Canyon    TX
# 461    4484               Naples    FL
# 462    4485           Santa Cruz    CA
#
# [463 rows x 3 columns]

# %%
city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 463 entries, 0 to 462
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CityID  463 non-null    int64
#  1   City    463 non-null    object
#  2   State   463 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 11.0+ KB

# %%
city.columns
# Out:
# Index(['CityID', 'City', 'State'], dtype='object')

# %%
city.State.unique()
# Out:
# array(['TX', 'OH', 'NY', 'NM', 'PA', 'IA', 'MA', 'CA', 'AK', 'MI', 'MD',
#        'NC', 'GA', 'NJ', 'AL', 'ME', 'LA', 'PR', 'MT', 'VA', 'IN', 'FL',
#        'ID', 'CO', 'KY', 'CT', 'SD', 'VT', 'MX', 'MO', 'IL', 'WY', 'UT',
#        'SC', 'WV', 'TN', 'WA', 'AR', 'OR', 'DE', 'NH', 'ND', 'AZ', 'WI',
#        'MS', 'HI', 'RI', 'NV', 'KS', 'NE', 'MN', 'OK', 'BA', 'GY', 'CH',
#        'SK', 'VI', 'BC', 'DC', 'IR', 'JA', 'CI', 'ON'], dtype=object)

# %%
city.State.value_counts()
# Out:
# NY    31
# CA    29
# TX    28
# FL    28
# NC    17
#       ..
# VT     1
# AK     1
# DC     1
# IR     1
# CI     1
# Name: State, Length: 63, dtype: int64

# %%
city.query("State=='NY'")
# Out:
#      CityID                City State
# 2      4003              Albany    NY
# 44     4045               Bronx    NY
# 46     4047            Brooklyn    NY
# 47     4048    Brooklyn Heights    NY
# 48     4049             Buffalo    NY
# 130    4131         Glens Falls    NY
# 143    4144            Hamilton    NY
# 150    4151           Hempstead    NY
# 163    4164              Ithaca    NY
# 191    4192            Lewiston    NY
# 201    4202         Loudonville    NY
# 237    4238        New Rochelle    NY
# 238    4239            New York    NY
# 241    4242       Niagara Falls    NY
# 274    4275        Poughkeepsie    NY
# 284    4285              Queens    NY
# 292    4293           Riverdale    NY
# 295    4296           Rochester    NY
# 326    4328     St. Bonaventure    NY
# 331    4333       Staten Island    NY
# 335    4337         Stony Brook    NY
# 338    4340            Syracuse    NY
# 358    4360              Vestal    NY
# 365    4367          West Point    NY
# ...

# %% [markdown]
# ## next data set

# %%
file_name_list[1]
# Out:
# 'WNCAATourneyDetailedResults.csv'

# %%
pd.read_csv(data_path+file_name_list[1])
# Out:
#      Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0      2010     138     3124      69     3201      55    N      0    28    57
# 1      2010     138     3173      67     3395      66    N      0    23    59
# 2      2010     138     3181      72     3214      37    H      0    26    57
# 3      2010     138     3199      75     3256      61    H      0    25    63
# 4      2010     138     3207      62     3265      42    N      0    24    68
# ..      ...     ...      ...     ...      ...     ...  ...    ...   ...   ...
# 688    2021     148     3376      62     3400      34    N      0    25    57
# 689    2021     148     3390      78     3257      63    N      0    30    68
# 690    2021     151     3112      69     3163      59    N      0    20    50
# 691    2021     151     3390      66     3376      65    N      0    25    60
# 692    2021     153     3390      54     3112      53    N      0    24    57
#
# ...

# %% [markdown]
# # creating datafram with variable name.

# %%
for i in range(0,14):
    print("variable_name-->",file_name_list[i][:-4],"file_name-->",file_name_list[i],"index_no-->",i)
#     display(pd.read_csv(data_path+file_name_list[i],encoding_errors='ignore').head(5))
#     
    globals()[file_name_list[i][:-4]]=pd.read_csv(data_path+file_name_list[i],encoding_errors='ignore')
    display(globals()[file_name_list[i][:-4]].head(5))
# Out:
# variable_name--> Conferences file_name--> Conferences.csv index_no--> 0
#   ConfAbbrev                   Description
# 0      a_sun       Atlantic Sun Conference
# 1      a_ten        Atlantic 10 Conference
# 2        aac  American Athletic Conference
# 3        acc     Atlantic Coast Conference
# 4        aec       America East Conference
# variable_name--> WNCAATourneyDetailedResults file_name--> WNCAATourneyDetailedResults.csv index_no--> 1
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2010     138     3124      69     3201      55    N      0    28    57
# 1    2010     138     3173      67     3395      66    N      0    23    59
# 2    2010     138     3181      72     3214      37    H      0    26    57
# 3    2010     138     3199      75     3256      61    H      0    25    63
# 4    2010     138     3207      62     3265      42    N      0    24    68
#
# ...

# %%
# WNCAATourneyDetailedResults             # uncomment & run it, it work like variable

# %% [markdown]
# data Section into four(4) part
#
# Data Section 1 in files-->
# [WTeams.csv, WSeasons.csv, WNCAATourneySeeds.csv, WRegularSeasonCompactResults.csv, WNCAATourneyCompactResults.csv, WSampleSubmissionStage1.csv]
#
# Data Section 2 in files-->
# [WRegularSeasonDetailedResults.csv, WNCAATourneyDetailedResults.csv]
#
# Data Section 3 in files-->
# [WRegularSeasonDetailedResults.csv, WNCAATourneyDetailedResults.csv]
#
# Data Section 4 in files-->
# [WTeamSpellings.csv, WNCAATourneySlots, Conferences.csv, WTeamConferences.csv]

# %% [markdown]
# # Seperate the dataset into section

# %%
# Data section 1
Data_section_1=[WTeams,
WSeasons,
WNCAATourneySeeds,
WRegularSeasonCompactResults,
WNCAATourneyCompactResults ,
WSampleSubmissionStage1]
for  i in Data_section_1:
    display(i.head(5))
# Out:
#    TeamID     TeamName
# 0    3101  Abilene Chr
# 1    3102    Air Force
# 2    3103        Akron
# 3    3104      Alabama
# 4    3105  Alabama A&M
#    Season              DayZero RegionW  RegionX  RegionY  RegionZ
# 0    1998  1997-10-27 00:00:00    East  Midwest  Mideast     West
# 1    1999  1998-10-26 00:00:00    East  Mideast  Midwest     West
# 2    2000  1999-11-01 00:00:00    East  Midwest  Mideast     West
# 3    2001  2000-10-30 00:00:00    East  Midwest  Mideast     West
# 4    2002  2001-10-29 00:00:00    East     West  Mideast  Midwest
#    Season Seed  TeamID
# 0    1998  W01    3330
# 1    1998  W02    3163
# 2    1998  W03    3112
# 3    1998  W04    3301
# 4    1998  W05    3272
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT
# 0    1998      18     3104      91     3202      41    H      0
# 1    1998      18     3163      87     3221      76    H      0
# 2    1998      18     3222      66     3261      59    H      0
# ...

# %%
# Data_section_2
Data_section_2=[WRegularSeasonDetailedResults , WNCAATourneyDetailedResults ]
for  i in Data_section_2:
    display(i.head(5))
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2010      11     3103      63     3237      49    H      0    23    54
# 1    2010      11     3104      73     3399      68    N      0    26    62
# 2    2010      11     3110      71     3224      59    A      0    29    62
# 3    2010      11     3111      63     3267      58    A      0    27    52
# 4    2010      11     3119      74     3447      70    H      1    30    74
#
#    WFGM3  WFGA3  WFTM  WFTA  WOR  WDR  WAst  WTO  WStl  WBlk  WPF  LFGM  LFGA  \
# 0      5      9    12    19   10   26    14   18     7     0   15    20    54
# 1      5     12    16    28   16   31    15   20     5     2   25    25    63
# 2      6     15     7    12   14   23    18   13     6     2   17    19    58
# 3      4     11     5     9    6   40    14   27     5    10   18    18    74
# 4      7     20     7    11   14   33    18   11     5     3   18    25    74
#
# ...

# %%
# Data_section_3
Data_section_3=[WRegularSeasonDetailedResults, WNCAATourneyDetailedResults]
for  i in Data_section_3:
    display(i.head(5))
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2010      11     3103      63     3237      49    H      0    23    54
# 1    2010      11     3104      73     3399      68    N      0    26    62
# 2    2010      11     3110      71     3224      59    A      0    29    62
# 3    2010      11     3111      63     3267      58    A      0    27    52
# 4    2010      11     3119      74     3447      70    H      1    30    74
#
#    WFGM3  WFGA3  WFTM  WFTA  WOR  WDR  WAst  WTO  WStl  WBlk  WPF  LFGM  LFGA  \
# 0      5      9    12    19   10   26    14   18     7     0   15    20    54
# 1      5     12    16    28   16   31    15   20     5     2   25    25    63
# 2      6     15     7    12   14   23    18   13     6     2   17    19    58
# 3      4     11     5     9    6   40    14   27     5    10   18    18    74
# 4      7     20     7    11   14   33    18   11     5     3   18    25    74
#
# ...

# %%
# Data_section_4
Data_section_4=[WTeamSpellings, WNCAATourneySlots, Conferences, WTeamConferences]
for  i in Data_section_4:
    display(i.head(5))
# Out:
#      TeamNameSpelling  TeamID
# 0    a&m-corpus chris    3394
# 1  a&m-corpus christi    3394
# 2         abilene chr    3101
# 3   abilene christian    3101
# 4   abilene-christian    3101
#    Slot StrongSeed WeakSeed
# 0  R1W1        W01      W16
# 1  R1W2        W02      W15
# 2  R1W3        W03      W14
# 3  R1W4        W04      W13
# 4  R1W5        W05      W12
#   ConfAbbrev                   Description
# 0      a_sun       Atlantic Sun Conference
# 1      a_ten        Atlantic 10 Conference
# 2        aac  American Athletic Conference
# 3        acc     Atlantic Coast Conference
# 4        aec       America East Conference
#    Season  TeamID ConfAbbrev
# 0    1998    3102        wac
# 1    1998    3103        mac
# 2    1998    3104        sec
# 3    1998    3106       swac
# 4    1998    3108       swac
